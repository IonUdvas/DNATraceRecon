# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
bma_data = pd.read_csv("../results/BMA Results(Realistic).csv")

# %%
bma_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3876 entries, 0 to 3875
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Length                3876 non-null   int64
#  1   No. of Transmits      3876 non-null   int64
#  2   Deletion Probability  3876 non-null   float64
#  3   Percentage Error      3876 non-null   float64
#  4   Time Taken            3876 non-null   float64
# dtypes: float64(3), int64(2)
# memory usage: 151.5 KB

# %%
bma_data.describe()
# Out:
#             Length  No. of Transmits  Deletion Probability  Percentage Error  \
# count  3876.000000       3876.000000           3876.000000       3876.000000
# mean     55.000000         27.000000              3.116667          6.771336
# std      27.389661         14.698835              2.574833         17.418102
# min      10.000000          3.000000              0.100000          0.000000
# 25%      30.000000         15.000000              1.375000          0.000000
# 50%      55.000000         27.000000              2.750000          0.100000
# 75%      80.000000         39.000000              4.125000          1.800000
# max     100.000000         51.000000             10.000000         99.700000
#
#         Time Taken
# count  3876.000000
# mean      2.247365
# std       1.467792
# min       0.133579
# 25%       1.121365
# 50%       1.986935
# 75%       3.125078
# max      13.829065

# %% [markdown]
# # Plots

# %%
# %matplotlib inline
bma_data.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'Length'}>,
#         <AxesSubplot:title={'center':'No. of Transmits'}>],
#        [<AxesSubplot:title={'center':'Deletion Probability'}>,
#         <AxesSubplot:title={'center':'Percentage Error'}>],
#        [<AxesSubplot:title={'center':'Time Taken'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix 
attributes = ["Length","No. of Transmits", "Deletion Probability","Percentage Error", "Time Taken"]
scatter_matrix(bma_data[attributes], figsize=(12,8))
# Out:
# array([[<AxesSubplot:xlabel='Length', ylabel='Length'>,
#         <AxesSubplot:xlabel='No. of Transmits', ylabel='Length'>,
#         <AxesSubplot:xlabel='Deletion Probability', ylabel='Length'>,
#         <AxesSubplot:xlabel='Percentage Error', ylabel='Length'>,
#         <AxesSubplot:xlabel='Time Taken', ylabel='Length'>],
#        [<AxesSubplot:xlabel='Length', ylabel='No. of Transmits'>,
#         <AxesSubplot:xlabel='No. of Transmits', ylabel='No. of Transmits'>,
#         <AxesSubplot:xlabel='Deletion Probability', ylabel='No. of Transmits'>,
#         <AxesSubplot:xlabel='Percentage Error', ylabel='No. of Transmits'>,
#         <AxesSubplot:xlabel='Time Taken', ylabel='No. of Transmits'>],
#        [<AxesSubplot:xlabel='Length', ylabel='Deletion Probability'>,
#         <AxesSubplot:xlabel='No. of Transmits', ylabel='Deletion Probability'>,
#         <AxesSubplot:xlabel='Deletion Probability', ylabel='Deletion Probability'>,
# ...

# %% [markdown]
# We will focus on the plots of Percentage Error and Time Taken v/s all other parameters.
#
# The noticable plot is Percentage Error v/s Time Taken, which shows that the algorithm, if it runs longer(i.e. on more transmits, or on more length), it does not guarantee that the Percentage Error will be low. All other graphs are as expected.

# %% [markdown]
# We now do some plots to reflect the performance of the algorithm by varying some parameters. **(Need to decide this part)**

# %% [markdown]
# | Constant | X-Axis | Y-Axis | Datasets |
# | :-: | :-: | :-: | :-: |
# | Length(50) | No of Transmits | % Error | Deletion Probability
# | Length(50) | No of Transmits | Time Taken | Deletion Probability
# | No of Transmits(30) | Length | % Error | Deletion Probability
# | No of Transmits(30) | Length | Time Taken | Deletion Probability
# | No of Transmits(9) | Length | % Error | Deletion Probability
# | No of Transmits(9) | Length | Time Taken | Deletion Probability
